# %% [markdown]
# ## Dataset contain information about coffee production and consumption.
# link keggle: https://www.kaggle.com/datasets/michals22/coffee-dataset
#
# All data are available from the official ICO website:
# https://www.ico.org/new_historical.asp
#
# **In thousand 60kg bags

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Nota : Verificar depois uma função para automatizar essa leitura de vários datasets dentro de um diretório e salvar essa função no seu utils_work.**

# %%
os.listdir('data_default/')
# Out:
# ['Coffee_import.csv',
#  'Coffee_green_coffee_inventorie.csv',
#  'Coffee_importers_consumption.csv',
#  'Coffee_re_export.csv',
#  'Coffee_production.csv',
#  'Coffee_export.csv',
#  'Coffee_domestic_consumption.csv']

# %%
# Read the datas: 
coffee_import = pd.read_csv('data_default/Coffee_import.csv')
coffee_green_inventorie = pd.read_csv('data_default/Coffee_green_coffee_inventorie.csv')
coffee_importers_consumption = pd.read_csv('data_default/Coffee_importers_consumption.csv')
coffee_re_export = pd.read_csv('data_default/Coffee_re_export.csv')
coffee_production = pd.read_csv('data_default/Coffee_production.csv')
coffee_export = pd.read_csv('data_default/Coffee_export.csv')
coffee_domestic_consumption = pd.read_csv('data_default/Coffee_domestic_consumption.csv')

# %%
coffee_import.sample(2)
# Out:
#           Country      1990      1991      1992      1993      1994      1995  \
# 18     Luxembourg         0         0         0         0         0         0
# 13        Hungary  34440000  38460000  31320000  40080000  46260000  31200000
#
#         1996      1997      1998  ...      2011      2012      2013      2014  \
# 18         0         0         0  ...  19560000  19380000  22680000  24780000
# 13  36180000  40500000  42960000  ...  38400000  44880000  33420000  49980000
#
#         2015      2016      2017      2018      2019  Total_import
# 18  22560000  23640000  22800000  25980000  24120000     415620000
# 13  42840000  43500000  43320000  46740000  46380000    1327440000
#
# [2 rows x 32 columns]

# %%
coffee_green_inventorie.sample(2)
# Out:
#       Country       1990      1991       1992       1993       1994  \
# 5     Germany  240000000  96000000  150000000  120000000  234000000
# 3     Finland   10560000  13380000   12780000   11280000   16920000
#
#         1995      1996       1997      1998  ...       2011       2012  \
# 5  138000000  96000000  114000000  96000000  ...  147720000  171540000
# 3   13200000   8400000   10860000   9720000  ...    4980000    4980000
#
#         2013       2014       2015       2016       2017       2018  \
# 5  158160000  187200000  211140000  239460000  216060000  211080000
# 3    4980000    4980000    4980000    4980000    4980000    4980000
#
#         2019  Total_inventorie
# 5  208740000        5179440000
# 3    4980000         219120000
#
# [2 rows x 32 columns]

# %%
coffee_importers_consumption.sample(2)
# Out:
#         Country     1990     1991      1992      1993      1994      1995  \
# 3      Bulgaria  6120000  1020000  10500000  19620000  21180000  23580000
# 25     Slovenia        0        0   6900000   8880000   9120000   8400000
#
#         1996      1997      1998  ...      2011      2012      2013      2014  \
# 3   14760000  16500000  19440000  ...  21600000  22560000  25140000  22560000
# 25   9840000   9660000   9720000  ...  12480000  11100000  11040000  11220000
#
#         2015      2016      2017      2018      2019  Total_import_consumption
# 3   24360000  27120000  24900000  25560000  25380000                 625080000
# 25  11280000  11580000  11400000  13080000  12240000                 300900000
#
# [2 rows x 32 columns]

# %%
coffee_re_export.sample(2)
# Out:
#        Country       1990       1991       1992       1993       1994  \
# 11     Germany  197520000  195120000  199080000  196920000  208140000
# 28       Japan    1200000    2040000    1620000    2040000    1620000
#
#          1995       1996       1997       1998  ...       2011       2012  \
# 11  193200000  216780000  236100000  243780000  ...  700980000  755400000
# 28     420000     360000    1140000     540000  ...    4800000    4260000
#
#          2013       2014       2015       2016       2017       2018  \
# 11  721200000  774660000  749760000  798780000  816000000  826200000
# 28    5520000    6660000    7020000    6660000    6780000    7440000
#
#          2019  Total_re_export
# 11  828060000      14558880000
# 28    9480000        134760000
#
# [2 rows x 32 columns]

# %%
coffee_production.sample(2)
# Out:
#      Country      Coffee type     1990/91      1991/92     1992/93  \
# 4    Ecuador  Arabica/Robusta  90240000.0  127440000.0  71100000.0
# 19  Tanzania  Arabica/Robusta  55920000.0   47400000.0  47160000.0
#
#         1993/94      1994/95      1995/96      1996/97     1997/98  ...  \
# 4   124140000.0  142560000.0  113280000.0  119580000.0  71460000.0  ...
# 19   44040000.0   40740000.0   53820000.0   45840000.0  37440000.0  ...
#
#        2011/12     2012/13     2013/14     2014/15     2015/16     2016/17  \
# 4   49500000.0  49680000.0  39960000.0  38640000.0  38640000.0  38700000.0
# 19  38460000.0  69060000.0  48660000.0  45180000.0  55800000.0  50760000.0
#
#        2017/18     2018/19     2019/20  Total_production
# 4   37440000.0  29760000.0  33540000.0      1.900380e+09
# 19  46980000.0  70500000.0  55560000.0      1.474680e+09
#
# [2 rows x 33 columns]

# %%
coffee_export.sample(2)
# Out:
#         Country      1990      1991      1992      1993      1994      1995  \
# 46  Timor-Leste         0         0         0         0         0         0
# 3       Burundi  35100000  41280000  38760000  25080000  30480000  31680000
#
#         1996      1997      1998  ...      2011      2012      2013      2014  \
# 46         0         0         0  ...   2340000   3360000   4200000   6660000
# 3   13440000  31740000  22440000  ...  13080000  23520000  11700000  15120000
#
#         2015      2016      2017      2018      2019  Total_export
# 46   4080000   4080000   5160000   7740000   7020000      68040000
# 3   13800000  12240000  10140000  12120000  17580000     646200000
#
# [2 rows x 32 columns]

# %%
coffee_domestic_consumption.sample(2)
# Out:
#                Country      Coffee type   1990/91   1991/92   1992/93  \
# 37             Jamaica          Arabica    420000    660000    360000
# 16  Dominican Republic  Arabica/Robusta  19200000  19200000  19200000
#
#      1993/94   1994/95   1995/96   1996/97   1997/98  ...   2011/12   2012/13  \
# 37    576000    900000    900000   1080000   1200000  ...    540000    540000
# 16  19200000  19800000  21000000  19500000  19500000  ...  22680000  22680000
#
#      2013/14   2014/15   2015/16   2016/17   2017/18   2018/19   2019/20  \
# 37    540000    540000    540000    540000    540000    540000    540000
# 16  22999980  23280000  23280000  23400000  23400000  23400000  22620000
#
#     Total_domestic_consumption
# 37                    18688020
# 16                   642823380
#
# [2 rows x 33 columns]

# %% [markdown]
# Observação: Os datasets importados acima demonstram resultados específicos de um atributo por países e os anos distribuídos.
#
# Dicionário de variáveis/atributos:
# - Exportação anual por países  - dataset: coffee_export
# - Importação anual por países - dataset: coffee_import
# - Consumo doméstico bi anual por países - dataset: coffee_domestic_consumption
# - Produção anual por países - dataset: coffee_production

# %% [markdown]
# ### Quais são os 10 principais paises exportadores de café?
# ### Quais são os 10 principais paises importadores ?
# ### Quais são os 10 principais consumidores ?
# ### Quais são os 10 principais produtores ?

# %%
#  Principais países exportadores de café: 
top_export = coffee_export[['Country', 'Total_export']].sort_values(by=['Total_export'], ascending=False).head(10)

# Principais importadores de café:  
top_import = coffee_import[['Country', 'Total_import']].sort_values(by=['Total_import'], ascending=False).head(10)

# Os principais paises consumidores
top_consum = coffee_domestic_consumption[['Country', 'Total_domestic_consumption']]
top_consum = top_consum.sort_values(by=['Total_domestic_consumption'], ascending=False).head(10)

# Principais Produtores: 
top_prod = coffee_production[['Country', 'Total_production']].sort_values(by='Total_production', ascending=False).head(10)

# %%
f, axs = plt.subplots(2, 1, figsize = (5,10))

sns.barplot(data = top_export, x='Total_export', y='Country', ax = axs[0])
sns.barplot(data = top_import, x='Total_import', y='Country', ax = axs[1])

axs[0].set_title('Principais Exportadores')
axs[1].set_title('Principais Importadores')
# Out:
# Text(0.5, 1.0, 'Principais Importadores')

# %%
f, axs = plt.subplots(2, 1, figsize = (5,10))

sns.barplot(data = top_consum, x='Total_domestic_consumption', y='Country', ax = axs[0])
sns.barplot(data = top_prod, x='Total_production', y='Country', ax = axs[1])

axs[0].set_title('Principais Consumidores')
axs[1].set_title('Principais Produtores')
# Out:
# Text(0.5, 1.0, 'Principais Produtores')

# %% [markdown]
# ## Qual a evolução de produção café dos 10 principais paises ?

# %%
production_Br = coffee_export.loc[coffee_export['Country']== 'Brazil'].T
production_Br.drop(['Country','Total_export'], axis=0, inplace=True)

# %%
production_Br.columns = ['Brazil']
production_Br.index.name = 'Ano'

# Plotline AnoxValor:
plt.figure(figsize = (20,5))
sns.lineplot(data= production_Br, x='Ano', y='Brazil', color='k', linestyle='--')
plt.grid('on')

# %%
top_export.head(10)
# Out:
#       Country  Total_export
# 2      Brazil   33807709056
# 51   Viet Nam   24924480000
# 6    Colombia   19878480000
# 25  Indonesia   10607940000
# 24      India    6933960000
# 19  Guatemala    6464340000
# 23   Honduras    5964840000
# 49     Uganda    5632200000
# 32     Mexico    5628000000
# 39       Peru    4903920000

# %%
data_prod = pd.DataFrame(columns=coffee_export.columns)
for country in top_export['Country']:
    production = coffee_export.loc[coffee_export['Country'] == country ]
    data_prod = pd.concat([data_prod, production]).reset_index(drop=True)

# %%
data_prod2 = coffee_export[coffee_export.Country.isin(top_export['Country'].unique())]
data_prod2
# Out:
#       Country        1990        1991        1992        1993        1994  \
# 2      Brazil  1016160000  1270980000  1127460000  1070280000  1036380000
# 6    Colombia   836640000   755940000   993840000   814080000   706080000
# 19  Guatemala   194400000   169920000   199680000   225060000   196440000
# 23   Honduras   104100000    86640000   117600000   102300000   103080000
# 24      India   118740000   103620000   108960000   126120000   149760000
# 25  Indonesia   414180000   370260000   276240000   339720000   276300000
# 32     Mexico   220980000   211860000   199920000   195840000   167340000
# 39       Peru    66300000    62520000    63660000    46500000    63420000
# 49     Uganda   141180000   125700000   117660000   109740000   202140000
# 51   Viet Nam    68700000    72060000   116280000   124320000   163260000
#
#          1995       1996        1997        1998  ...        2011        2012  \
# ...
